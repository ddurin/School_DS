# %%
import pandas as pd
import pickle
import sqlite3

# %%
pd.read_pickle('df_nashdomrf.pkl')
# Out:
#           id  hobjId    pdId  region  \
# 0      13399   34754   28141      72
# 1      13397   37201   28141      72
# 2      13383   39024   28105      72
# 3      13398   37165   28141      72
# 4      13391   37219   28101      72
# ...      ...     ...     ...     ...
# 11709  56129  136843  794938      32
# 11710  56132  136846  794938      32
# 11711  56131  136845  794938      32
# 11712  56130  136844  794938      32
# 11713  51137  131791  582963      32
#
#                                                  address  floorMin  floorMax  \
# 0                        г Тюмень, ул Профсоюзная, д. 56         1         1
# 1                        г Тюмень, ул Профсоюзная, д. 56         6        12
# 2                        г Тюмень, ул Профсоюзная, д. 56         4        20
# 3                        г Тюмень, ул Профсоюзная, д. 56         7        10
# 4                        г Тюмень, ул Профсоюзная, д. 56         3        12
# ...

# %%
unpickled_df_nashdomrf = pd.read_pickle('df_nashdomrf.pkl')
#print(unpickled_df_nashdomrf)

# %%
unpickled_df_nashdomrf.to_csv('./new_df_nashdomrf.csv')

# %%
unpickled_df_nashdomrf.to_pickle("./new_df_nashdomrf.pkl")

# %%
conn = sqlite3.connect('test_database')
unpickled_df_nashdomrf.to_sql('nashdomrf', conn, if_exists='replace', index = False)
conn.commit()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[15], line 2
#       1 conn = sqlite3.connect('test_database')
# ----> 2 unpickled_df_nashdomrf.to_sql('nashdomrf', conn, if_exists='replace', index = False)
#       3 conn.commit()
#       4 conn.close()
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:3087, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2889 """
# ...
